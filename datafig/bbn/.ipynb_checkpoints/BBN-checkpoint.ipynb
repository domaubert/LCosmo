# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import simps
import scipy.constants as pcst
plt.rcParams['figure.figsize'] = (7.0, 7.0)

# %%
data=np.loadtxt('bbn.txt',skiprows=1)
eta=data[:,0]
Yp=data[:,1]
D=data[:,2]
He3=data[:,3]
Li7=data[:,4]

# %%
eta
# Out:
# array([  1.00000000e-10,   1.50000000e-10,   2.00000000e-10,
#          2.50000000e-10,   3.00000000e-10,   3.50000000e-10,
#          4.00000000e-10,   4.50000000e-10,   5.00000000e-10,
#          5.50000000e-10,   6.00000000e-10,   6.50000000e-10,
#          7.00000000e-10,   7.50000000e-10,   8.00000000e-10,
#          8.50000000e-10,   9.00000000e-10,   9.50000000e-10])

# %%
ee=np.logspace(-10.2,-8.9)
uu=np.logspace(-11,0)



plt.figure()


plt.subplot(311)
plt.plot(eta,Yp)
plt.fill_between(ee,ee*0+0.241,y2=ee*0+0.249,alpha=0.3)
plt.fill_betweenx(uu,uu*0+6.03e-10,x2=uu*0+6.15e-10,alpha=0.3)


plt.xscale('log')
plt.legend(['Yp'])
plt.xlim([1e-10,1e-9])
plt.ylim([0.23,0.26])

plt.subplot(312)
plt.plot(eta,D)

plt.plot(eta,He3)
plt.fill_between(ee,ee*0+2.49e-5,y2=ee*0+2.57e-5,alpha=0.3)
plt.fill_betweenx(uu,uu*0+6.03e-10,x2=uu*0+6.15e-10,alpha=0.3)


plt.xlim([1e-10,1e-9])

plt.ylim([5e-6,5e-4])



plt.legend(['D/H','He3/H'])



plt.xscale('log')
plt.yscale('log')

plt.subplot(313)
plt.plot(eta,Li7)
plt.fill_between(ee,ee*0+1.3e-10,y2=ee*0+1.9e-10,alpha=0.3)
plt.fill_betweenx(uu,uu*0+6.03e-10,x2=uu*0+6.15e-10,alpha=0.3)
plt.ylim([5e-11,1e-9])





plt.legend(['Li7/H'])
plt.xlim([1e-10,1e-9])
plt.xlabel(r'$\eta$')


plt.xscale('log')
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="700">
